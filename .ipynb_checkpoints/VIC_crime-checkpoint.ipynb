# %% [markdown]
# # Crime rates in Victoria - spatial visualisation

# %% [markdown]
# <img src="images/Crimestoppers_RGB.png", width=250, height=250, ALIGN="right">
# This instructional notebook investigates the reported crime rates in Victoria, Australia. This is by no means production code, it's designed to explain some of the steps involved in analysing and visualising data spatially.
#
# Author: [Paul Geil](http://www.ph.unimelb.edu.au/~geilp/index.html)
#
# Data used here include:
#
# - Crime by location from the [Crime Statistics Agency](https://www.crimestatistics.vic.gov.au/) (CSA)
# - Victorian Local Government Areas from [data.gov.au](https://data.gov.au/dataset/vic-local-government-areas-psma-administrative-boundaries)

# %% [markdown]
# ## Table of contents

# %% [markdown]
# - [1. Introduction](#1.-Introduction)
#
#
# - [2. Local Government Areas](#2.-Victorian-Local-Government-Areas)
#
#
# - [3. Crime rates](#3.-Crime-rates)
#     * [3.1 Just the numbers](#3.1-Just-the-numbers)
#     * [3.2 Spatial visualisation](#3.2-Spatial-visualisation)
#
#
# - [4. Digging deeper into the crime statistics](#4.-Digging-deeper-into-the-crime-statistics)
#     * [4.1 Crime rate by division](#4.1-Crime-rate-by-division)
#     * [4.2 Crime rate by subdivision](#4.2-Crime-rate-by-subdivision)
#
#
# - [5. Widgets](#5.-Widgets)
#
#
# - [6. Final remarks](#6.-Final-remarks)

# %% [markdown]
# ## 1. Introduction

# %% [markdown]
# [[ go back to the top ]](#Table-of-contents)

# %% [markdown]
# This notebook uses several Python packages. Some come standard with the [Anaconda Python distribution](http://continuum.io/downloads), some do not. The primary libraries are:
#
# * **[NumPy](http://www.numpy.org/)**: a library which adds support for large, multi-dimensional arrays and matrices, with a large collection of high-level mathematical functions to operate on these arrays.
# * **[pandas](https://pandas.pydata.org/)**: a library providing high-performance, easy-to-use data structures and data analysis tools.
# * **[json](https://www.json.org/)**: a decoder/encoder for JSON-formatted files. JSON (JavaScript Object Notation) is a lightweight data-interchange format.
# * **[folium](https://folium.readthedocs.io/en/latest/)**: an interactive spatial visualisation module using Leaflet maps.
# * **[bokeh](https://bokeh.pydata.org/en/latest/)**: an interactive visualisation library that targets modern web browsers for presentation.
# * **[matplotlib](https://matplotlib.org/)**: a basic plotting library; most other plotting libraries are built on top of it.
# * **[seaborn](https://seaborn.pydata.org/)**: an advanced statistical plotting library.
# * **[ipywidgets](https://ipywidgets.readthedocs.io/en/stable/index.html)**: a library for including interative widgets in jupyter notbooks.
#
# To make sure you have all of the packages you need, install them with `conda`:
#
#     conda install numpy pandas matplotlib seaborn
#
# Alternatively, if you can install the packages with [pip](https://pip.pypa.io/en/stable/installing/) (a Python package manager):
#
#     pip install numpy pandas matplotlib seaborn

# %% [markdown]
# ## 2. Victorian Local Government Areas

# %% [markdown]
# [[ go back to the top ]](#Table-of-contents)

# %% [markdown]
# The statistics explored in this notebook have been aggregated by local government area (LGA). LGA boundary data is available from the Australain Government data repository [here](https://data.gov.au/dataset/vic-local-government-areas-psma-administrative-boundaries).
#
# For the purpose of this notebook we'll use data in the form of a GeoJSON file. [GeoJSON](http://geojson.org/) is a geospatial data interchange format based on JavaScript Object Notation (JSON).
#
# Governmental/professional spatial (Geo)JSON files are typically large due to the large number of vertices (i.e. resolution). It's possible to reduce their resolution (this process is called *simplification*). One example command-line tool for this is [`mapshaper`](https://github.com/mbloch/mapshaper). I've used `mapshaper` to reduce the GeoJSON datafile from 18.8MB to 500kb. The bash script I've used (`geojson_simplify.sh`) can be found in the `data` directory of this repo.

# %%
import json

with open('data/VIC_LGA_simplified.geojson') as f:
    json_data = json.load(f)

# %% [markdown]
# A quick way to visualise GeoJSON data is with the python module `folium`. Let's take a look at the Victorian LGA boundaries. This map is intereactive - explore!

# %%
kw_VIC = {'location': [-36.5, 145.], 'zoom_start': 7}

import folium
from folium import GeoJson

m = folium.Map(tiles='cartodbpositron', **kw_VIC)
GeoJson(json_data).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# While `folium` is an easy-to-use module, it does lack some features and aesthetics. We'll use `bokeh` for the rest of this notebook. In order to do so, we need to do some manual extraction of data from the GeoJSON file, so let's take a closer look at the structure and contents of the file.
#
# The GeoJSON file is a collection of *features*. Each feature in the file contains data for an individual LGA. The first feature contains the following data:

# %%
json_data['features'][0]
# Out:
# {'geometry': {'coordinates': [[[144.99705204, -37.88386502],
#     [145.00003579, -37.86645509],
#     [145.009166, -37.86759616],
#     [145.01052136, -37.8602253],
#     [145.01513662, -37.86084043],
#     [145.03260723, -37.86846286],
#     [145.04015202, -37.87510781],
#     [145.04656539, -37.87701487],
#     [145.05371815, -37.88333843],
#     [145.07211172, -37.88493939],
#     [145.07818255, -37.8871519],
#     [145.0742074, -37.908145],
#     [145.08530643, -37.90951477],
#     [145.08247563, -37.92399779],
#     [145.07953336, -37.93875232],
#     [145.03440114, -37.93302807],
#     [145.02245805, -37.92061192],
#     [145.02598778, -37.90216533],
#     [145.00632168, -37.89982062],
#     [145.00103804, -37.88858906],
#     [144.99705204, -37.88386502]]],
#   'type': 'Polygon'},
#  'id': 'ckan_bdf92691_c6fe_42b9_a0e2_a4cd716fa811.1',
#  'properties': {'dt_create': '2011-11-29Z',
#   'dt_retire': None,
#   'highlight': {},
#   'lg_ply_pid': '281',
#   'lga_pid': 'VIC89',
#   'style': {},
#   'vic_lga__1': None,
#   'vic_lga__2': 'GLEN EIRA CITY',
#   'vic_lga__3': 'GLEN EIRA',
#   'vic_lga__4': None,
#   'vic_lga__5': '2',
#   'vic_lga_sh': '2011-11-29Z'},
#  'type': 'Feature'}

# %% [markdown]
# *geometry* contains a list of *coordinates* (in the form of a polygon, or linear ring of latitudes and longitudes) representing the LGA boundary. *properties* contains additional data about the LGA (such as names and ids). We'll be using the geometric data, the `vic_lga__3` property (LGA name) and the `lg_ply_pid` property (a unique identifier for each polygon).
#
# Note that some LGAs have multiple, unconnected polygons (e.g. Bass Coast), therefore the mapping from `lg_ply_pid` to `vic_lga__3` is many-to-one. Also, there are some features in the collection that don't have geometric data.
#
# Let's extract the data we need from all features with geometric data, and for later convenience put this data into a `pandas` dataframe.. At the same time, we can write a [python dictionary](https://docs.python.org/2/tutorial/datastructures.html#dictionaries) that links unique polygon identifiers to their LGA name.

# %%
names = []       # Name of LGA polygon belongs to
unique_ids = []  # Unique id of polygon
xs = []          # Longitudes
ys = []          # Latitudes
id_dict = {}
for feat in json_data['features']:
    if feat["geometry"] is not None:
        name = feat["properties"]['vic_lga__3']
        unique_id = feat["properties"]['lg_ply_pid']
        names.append(name)
        unique_ids.append(unique_id)
        xs.append([x[0] for x in feat["geometry"]["coordinates"][0]])
        ys.append([y[1] for y in feat["geometry"]["coordinates"][0]])
        id_dict[unique_id] = name
        
import pandas as pd

data = [('Unique ID', unique_ids), ('LGA', names), ('Longs', xs), ('Lats', ys)]
json_df = pd.DataFrame.from_items(data)

# %% [markdown]
# The first 5 rows of data are:

# %%
json_df.head()
# Out:
#   Unique ID                LGA  \
# 0       281          GLEN EIRA
# 1       283  GREATER DANDENONG
# 2       287               HUME
# 3       292        MARIBYRNONG
# 4       295             MONASH
#
#                                                Longs  \
# 0  [144.99705204, 145.00003579, 145.009166, 145.0...
# 1  [145.14170184, 145.14344006, 145.15672631, 145...
# 2  [144.67237956, 144.66474887, 144.65671888, 144...
# 3  [144.90262481, 144.90406003, 144.91571619, 144...
# 4  [145.14170184, 145.08247563, 145.08530643, 145...
#
#                                                 Lats
# 0  [-37.88386502, -37.86645509, -37.86759616, -37...
# 1  [-37.931386, -37.92460615, -37.93314598, -37.9...
# 2  [-37.56779468, -37.55938401, -37.55325753, -37...
# 3  [-37.78966222, -37.79183009, -37.79678636, -37...
# 4  [-37.931386, -37.92399779, -37.90951477, -37.9...

# %% [markdown]
# We'll revisit this data later when we try to merge crime rate data.

# %% [markdown]
# ## 3. Crime rates

# %% [markdown]
# [[ go back to the top ]](#Table-of-contents)

# %% [markdown]
# ### 3.1 Just the numbers

# %% [markdown]
# [[ go back to the top ]](#Table-of-contents)

# %% [markdown]
# Crime by location (LGA) for the year ending June 2017 data is available from the Crime Statistics Agency [here](https://www.crimestatistics.vic.gov.au/crime-statistics/latest-crime-data/download-data-4) as a Comma-Spearated Values (CSV) file.
#
# Let's explore the dataset using `pandas`.

# %%
with open('data/Crime by location_2_LGA - year ending June 2017.csv') as f:
    crime_df = pd.read_csv(f, thousands=',')

# %% [markdown]
# The first 5 rows of data are:

# %%
crime_df.head()
# Out:
#   Local Government Area (LGA)  Offence Count  LGA ERP  Victorian ERP
# 0                      ALPINE            381    11817        6157538
# 1                      ARARAT           1342    10884        6157538
# 2                    BALLARAT          11991   105127        6157538
# 3                     BANYULE           9658   128469        6157538
# 4                  BASS COAST           2655    33648        6157538

# %% [markdown]
# The CSA [Explanatory Notes](https://www.crimestatistics.vic.gov.au/about-the-data/explanatory-notes) provide additional information about the data the CSA receives from Victoria Police, how it is processed and how to interpret the summary statistics. From these notes we find that ERP stands for Estimated Resident Population. This can be used to calculate the offence rate per 100000 people in the LGA by
#
# Rate = (Offence count / LGA ERP) * 100000
#
# Doing this we have:

# %%
crime_df['Rate'] = (crime_df['Offence Count'] / crime_df['LGA ERP'] * 100000).round().astype('int')
crime_df.head()
# Out:
#   Local Government Area (LGA)  Offence Count  LGA ERP  Victorian ERP   Rate
# 0                      ALPINE            381    11817        6157538   3224
# 1                      ARARAT           1342    10884        6157538  12330
# 2                    BALLARAT          11991   105127        6157538  11406
# 3                     BANYULE           9658   128469        6157538   7518
# 4                  BASS COAST           2655    33648        6157538   7891

# %% [markdown]
# For simplicity, let's tidy things up a little.
#
# The `Victorian ERP` column has only one unique value (it's just the Victorian population). Rather than keep the whole column let's just assign the value to the variable `Victorian_ERP`. We may use it later. We won't be needing the Offence Count, LGA ERP or Victorian ERP columns from hereon so let's drop them. While we're at it, let's shorten the `Local Government Area (LGA)` column title to `LGA`.

# %%
Victorian_ERP = crime_df['Victorian ERP'][0]
crime_df = crime_df.drop(['Offence Count', 'LGA ERP', 'Victorian ERP'], axis=1)
crime_df.rename(columns = {'Local Government Area (LGA)':'LGA'}, inplace=True)
crime_df.head()
# Out:
#           LGA   Rate
# 0      ALPINE   3224
# 1      ARARAT  12330
# 2    BALLARAT  11406
# 3     BANYULE   7518
# 4  BASS COAST   7891

# %% [markdown]
# Out of interest, let's sort the LGAs with respect to crime rate (descending). The five LGAs with highest crime rates for 2017 are:

# %%
crime_df.sort_values(by='Rate', ascending=False).head()
# Out:
#                    LGA   Rate
# 43           MELBOURNE  25412
# 36             LATROBE  18884
# 76               YARRA  14146
# 27  GREATER SHEPPARTON  12964
# 31             HORSHAM  12933

# %% [markdown]
# The five LGAs with lowest crime rates for 2017 are:

# %%
crime_df.sort_values(by='Rate', ascending=False).tail()
# Out:
#               LGA  Rate
# 67         TOWONG  3631
# 23  GOLDEN PLAINS  3507
# 0          ALPINE  3224
# 10         BULOKE  3100
# 33         INDIGO  2968

# %% [markdown]
# We can get a better idea of the distribution in crime rates in the LGAs through a histogram.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

ax = sns.distplot(crime_df['Rate'], bins=20, rug=True, kde=False)
ax.set_title('VIC crime rates (all crime, year ending June 2017)')
ax.set(xlabel='Rate per 100,000 population')
plt.show()

# %% [markdown]
# This looks fairly [normal](https://en.wikipedia.org/wiki/Normal_distribution) with the exception of two outliers. More useful information can be taken from a box plot.

# %%
flierprops = dict(marker='o', markerfacecolor='gray', markersize=6)
ax = sns.boxplot(x=crime_df['Rate'], width=0.5, flierprops=flierprops)
ax.set_title('VIC crime rates (all crime, year ending June 2017)')
ax.set(xlabel='Rate per 100,000 population')
plt.show()

# %% [markdown]
# The box shows the quartiles of the dataset while the whiskers extend to show the rest of the distribution, except for points that are determined to be outliers (using a method that is a function of the inter-quartile range).
#
# Which LGAs do these outliers correspond to? They are just the two LGAs with highest rates: Melbourne and La Trobe. It may be interesting to follow up on these LGAs, adding more data (e.g. average unemployment rate) and testing for a correlation.

# %% [markdown]
# ### 3.2 Spatial visualisation

# %% [markdown]
# [[ go back to the top ]](#Table-of-contents)

# %% [markdown]
# We should first check if the set of LGAs in the two datafiles (GeoJSON and CSV) match. To do this we can look at their differences.

# %%
print(list(set(json_df['LGA']) - set(crime_df['LGA'])))
# Out:
# ['MOUNT BULLER ALPINE RESORT (UNINC)', 'MOUNT HOTHAM ALPINE RESORT (UNINC)', 'LAKE MOUNTAIN ALPINE RESORT (UNINC)', 'GABO ISLAND (UNINC)', 'MOUNT STIRLING ALPINE RESORT (UNINC)', 'FALLS CREEK ALPINE RESORT (UNINC)', 'COLAC OTWAY', 'MOUNT BAW BAW ALPINE RESORT (UNINC)', 'FRENCH-ELIZABETH-SANDSTONE ISLANDS (UNINC)']

# %% [markdown]
# We want to be able to check the crime rate for any LGA in Victoria. If there are no crime data available then we should be able to see that is the case (e.g. a [`NaN`](https://docs.scipy.org/doc/numpy-1.13.0/user/misc.html) for the rate value). One way to do this is to merge the crime rates we have calculated into the spatial dataframe. However, the rows in the spatial dataframe corresponding to polygons for LGAs we don't have crime data for will not remain after merging. Therefore, we need to create a separate dataframe for any missing spatial data and append it to the merged dataframe. Below, I've written an ad hoc function (`fill_missing_LGAs`) to just this.
#
# Comparing the sets of LGAs, we see that there are no crime data for LGAs in the GeoJSON file which end with (UNINC).
#
# There is another difference though, that if not treated manually will lead to an omission: COLAC OTWAY. The name of this LGA is hyphenated in the crime data, but not in the GeoJSON file. To fix this, let's rename the LGA name in the crime data to match the json data before merging the dataframes.

# %%
crime_df.replace('COLAC-OTWAY', 'COLAC OTWAY', inplace=True)

# %% [markdown]
# The missing rows are:

# %%
print(list(set(json_df['LGA']) - set(crime_df['LGA'])))
# Out:
# ['MOUNT BULLER ALPINE RESORT (UNINC)', 'MOUNT HOTHAM ALPINE RESORT (UNINC)', 'LAKE MOUNTAIN ALPINE RESORT (UNINC)', 'GABO ISLAND (UNINC)', 'MOUNT STIRLING ALPINE RESORT (UNINC)', 'FALLS CREEK ALPINE RESORT (UNINC)', 'MOUNT BAW BAW ALPINE RESORT (UNINC)', 'FRENCH-ELIZABETH-SANDSTONE ISLANDS (UNINC)']

# %%
def fill_missing_LGAs(rate_df, spatial_df):
    '''
    Adds missing LGA rows in rate_df.
    '''
    import numpy as np
    spatial_LGA_list = list(set(spatial_df['LGA']) - set(rate_df['LGA']))
    rates = [np.nan for lga in spatial_LGA_list]
    #rates = np.zeros(len(spatial_LGA_list))
    data = [('LGA', spatial_LGA_list), ('Rate', rates)]
    missing_df = pd.DataFrame.from_items(data)
    return rate_df.append(missing_df)

# %% [markdown]
# Append missing data and merge...

# %%
new_crime_df = fill_missing_LGAs(crime_df, json_df).reset_index(drop=True)
df_merged = json_df.merge(new_crime_df, how='right', on='LGA')
#df_merged

# %% [markdown]
# We can now visualise the crime rate data we calculated above using a [choropleth](https://en.wikipedia.org/wiki/Choropleth_map).

# %%
from bokeh.models import ColumnDataSource, HoverTool, LogTicker, LinearColorMapper, ColorBar
from bokeh.plotting import figure, save, output_notebook, show
from bokeh.palettes import YlOrRd7
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="8d306489-cc11-4f88-a0e3-81d2441907ae">Loading BokehJS ...</span>
#     </div>

# %%
custom_palette = YlOrRd7[::-1][1:]
color_mapper = LinearColorMapper(palette=custom_palette, low=df_merged['Rate'].min(), high=df_merged['Rate'].max())

source = ColumnDataSource(data=dict(
    x=df_merged['Longs'], y=df_merged['Lats'],
    name=df_merged['LGA'], rate=df_merged['Rate']))

TOOLS = "pan,wheel_zoom,reset,hover,save"

p = figure(
    title="VIC crime rates (all crime, year ending June 2017)", tools=TOOLS,
    x_axis_location=None, y_axis_location=None,
    plot_width=850, plot_height=600
)
p.grid.grid_line_color = None
p.patches('x', 'y', source=source,
          fill_color={'field': 'rate', 'transform': color_mapper},
          fill_alpha=0.8, line_color='black', line_width=0.3)

color_bar = ColorBar(color_mapper=color_mapper, ticker=LogTicker(),
                     label_standoff=6, border_line_color=None,
                     location=(480,560), orientation='horizontal',
                     height=15, width=300,
                     background_fill_alpha=0, scale_alpha=0.8,
                     title='Rate per 100,000 population'
                     )
p.add_layout(color_bar, 'center')

hover = p.select_one(HoverTool)
hover.point_policy = "follow_mouse"
hover.tooltips = [("LGA", "@name"),("Rate", "@rate")]

show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="55e19bf5-afae-47bb-a438-a88d3aa1a8e3"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("55e19bf5-afae-47bb-a438-a88d3aa1a8e3");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("55e19bf5-afae-47bb-a438-a88d3aa1a8e3");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '55e19bf5-afae-47bb-a438-a88d3aa1a8e3' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"32e772d3-6755-4f4a-baa1-c903f822b583":{"roots":{"references":[{"attributes":{"callback":null},"id":"7e84b9b6-98b5-4dde-95ca-9364e67a8510","type":"DataRange1d"},{"attributes":{"plot":{"id":"ef035055-5bef-4e76-98e0-17cca81e834c","subtype":"Figure","type":"Plot"}},"id":"68dfb3a0-961d-4241-98ee-4ad5e00c6763","type":"ResetTool"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"ff2b9808-3597-451f-bd94-5d2cd1737304","type":"PanTool"},{"id":"6ff318c3-7ba0-43c5-9879-9e66bfe6a957","type":"WheelZoomTool"},{"id":"68dfb3a0-961d-4241-98ee-4ad5e00c6763","type":"ResetTool"},{"id":"cc0daf38-adc4-4947-9c8b-b2380c62c5d1","type":"HoverTool"},{"id":"0466d9cd-190d-4289-b889-5f31e3123a0b","type":"SaveTool"}]},"id":"ccc44c39-57df-4d7e-ad10-df6b82488249","type":"Toolbar"},{"attributes":{"background_fill_alpha":{"value":0},"color_mapper":{"id":"19461f90-e3ab-4fba-b740-c8984b5127c9","type":"LinearColorMapper"},"formatter":{"id":"8f6999c2-c1cb-4655-9ef4-764714f06509","type":"BasicTickFormatter"},"height":15,"label_standoff":6,"location":[480,560],"orientation":"horizontal","plot":{"id":"ef035055-5bef-4e76-98e0-17cca81e834c","subtype":"Figure","type":"Plot"},"scale_alpha":0.8,"ticker":{"id":"cfb44cae-46ee-419f-abe3-fc7d441a7235","type":"LogTicker"},"title":"Rate per 100,000 population","width":300},"id":"8666192c-2cda-4778-9ff0-548819d0067d","type":"ColorBar"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":0.3},"xs":{"field":"x"},"ys":{"field":"y"}},"id":"b7d35c76-519d-4f46-9a2d-b805511ce7b8","type":"Patches"},{"attributes":{"callback":null},"id":"cc2185d8-ad36-43c0-ba79-593418839a38","type":"DataRange1d"},{"attributes":{},"id":"6050f2f1-20c5-4dc9-8187-7329fa21fd76","type":"BasicTicker"},{"attributes":{"grid_line_color":{"value":null},"plot":{"id":"ef035055-5bef-4e76-98e0-17cca81e834c","subtype":"Figure","type":"Plot"},"ticker":{"id":"6050f2f1-20c5-4dc9-8187-7329fa21fd76","type":"BasicTicker"}},"id":"d37abed9-7ef5-4b78-a25a-619c9a7b2b56","type":"Grid"},{"attributes":{"plot":null,"text":"VIC crime rates (all crime, year ending June 2017)"},"id":"69392ce4-87eb-483a-ab61-74949663fcb4","type":"Title"},{"attributes":{},"id":"14690337-6de4-46c0-8835-69ad88645831","type":"BasicTicker"},{"attributes":{"dimension":1,"grid_line_color":{"value":null},"plot":{"id":"ef035055-5bef-4e76-98e0-17cca81e834c","subtype":"Figure","type":"Plot"},"ticker":{"id":"14690337-6de4-46c0-8835-69ad88645831","type":"BasicTicker"}},"id":"b8d5799c-153c-4f41-b766-665fcfac7572","type":"Grid"},{"attributes":{"plot":{"id":"ef035055-5bef-4e76-98e0-17cca81e834c","subtype":"Figure","type":"Plot"}},"id":"ff2b9808-3597-451f-bd94-5d2cd1737304","type":"PanTool"},{"attributes":{},"id":"8f6999c2-c1cb-4655-9ef4-764714f06509","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"ef035055-5bef-4e76-98e0-17cca81e834c","subtype":"Figure","type":"Plot"}},"id":"6ff318c3-7ba0-43c5-9879-9e66bfe6a957","type":"WheelZoomTool"},{"attributes":{"callback":null,"plot":{"id":"ef035055-5bef-4e76-98e0-17cca81e834c","subtype":"Figure","type":"Plot"},"point_policy":"follow_mouse","tooltips":[["LGA","@name"],["Rate","@rate"]]},"id":"cc0daf38-adc4-4947-9c8b-b2380c62c5d1","type":"HoverTool"},{"attributes":{"plot":{"id":"ef035055-5bef-4e76-98e0-17cca81e834c","subtype":"Figure","type":"Plot"}},"id":"0466d9cd-190d-4289-b889-5f31e3123a0b","type":"SaveTool"},{"attributes":{"data_source":{"id":"e3827173-ce20-4e36-b2e1-feccac62bf06","type":"ColumnDataSource"},"glyph":{"id":"6565d701-bdb1-4140-8833-bfd3b61bd031","type":"Patches"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"b7d35c76-519d-4f46-9a2d-b805511ce7b8","type":"Patches"},"selection_glyph":null},"id":"7dc68031-56ba-4a94-9d92-202180965b22","type":"GlyphRenderer"},{"attributes":{},"id":"05ce0030-fa02-438b-b440-c7db4a95395c","type":"ToolEvents"},{"attributes":{"high":2541 ...

# %% [markdown]
# As you can see, the high crime rate outliers clearly stand out.

# %% [markdown]
# ## 4. Digging deeper into the crime statistics

# %% [markdown]
# [[ go back to the top ]](#Table-of-contents)

# %% [markdown]
# So far we've only looked at the crime rates for all crimes taken together - we've ignored the type of offence because the dataset we've been working with doesn't include that information. We've also looked at only one year (2017).
#
# In order to dig deeper into the crime statistics we need more data. Another CSV datafile available from the CSA is `Crime by location_1_Region_PSA_LGA_OffenceType - year ending June 2017.csv`. Here's what the first few rows look like.

# %%
with open('data/Crime by location_1_Region_PSA_LGA_OffenceType - year ending June 2017.csv') as f:
    crime2_df = pd.read_csv(f, thousands=',')
crime2_df.head()
# Out:
#    Jul - Jun reference period       Police Region Police Service Area  \
# 0                        2017  1 North West Metro             Banyule
# 1                        2017  1 North West Metro             Banyule
# 2                        2017  1 North West Metro             Banyule
# 3                        2017  1 North West Metro             Banyule
# 4                        2017  1 North West Metro             Banyule
#
#   Local Government Area         CSA Offence Division  \
# 0               Banyule  A Crimes against the person
# 1               Banyule  A Crimes against the person
# 2               Banyule  A Crimes against the person
# 3               Banyule  A Crimes against the person
# 4               Banyule  A Crimes against the person
#
#              CSA Offence Subdivision  \
# 0  A10 Homicide and related offences
# 1   A20 Assault and related offences
# 2   A20 Assault and related offences
# 3   A20 Assault and related offences
# 4   A20 Assault and related offences
#
#                                    CSA Offence Group  Offence Count  LGA ERP  \
# 0                  A10 Homicide and related offences              2   128469
# 1                            A211 FV Serious assault            143   128469
# 2                        A212 Non-FV Serious assault            121   128469
# 3  A22 Assault police, emergency services or othe...             52   128469
# 4                             A231 FV Common assault            196   128469
#
#    Victorian ERP
# 0        6157538
# 1        6157538
# 2        6157538
# 3        6157538
# 4        6157538

# %%
print('Dataframe shape = {0}'.format(crime2_df.shape))
print()
print('Unique entries in Jul - Jun reference period column:')
print('{0}'.format(crime2_df['Jul - Jun reference period'].unique()))
print()
print('Unique entries in CSA Offence Division:')
print('{0}'.format(crime2_df['CSA Offence Division'].unique()))
print()
print('Unique entries in CSA Offence Subdivision:')
print('{0}'.format(crime2_df['CSA Offence Subdivision'].unique()))
# Out:
# Dataframe shape = (26635, 10)
#
# Unique entries in Jul - Jun reference period column:
# [2017 2016 2015 2014 2013]
#
# Unique entries in CSA Offence Division:
# ['A Crimes against the person' 'B Property and deception offences'
#  'C Drug offences' 'D Public order and security offences'
#  'E Justice procedures offences' 'F Other offences']
#
# Unique entries in CSA Offence Subdivision:
# ['A10 Homicide and related offences' 'A20 Assault and related offences'
#  'A30 Sexual offences' 'A40 Abduction and related offences' 'A50 Robbery'
#  'A60 Blackmail and extortion'
#  'A70 Stalking, harassment and threatening behaviour'
#  'A80 Dangerous and negligent acts endangering people' 'B10 Arson'
#  'B20 Property damage' 'B30 Burglary/Break and enter' 'B40 Theft'
#  'B50 Deception' 'C10 Drug dealing and trafficking'
#  'C20 Cultivate or manufacture drugs' 'C30 Drug use and possession'
#  'D10 Weapons and explosives offences'
#  'D20 Disorderly and offensive conduct' 'D30 Public nuisance offences'
#  'D40 Public security offences' 'E10 Justice procedures'
#  'E20 Breaches of orders' 'F10 Regulatory driving offences'
#  'F20 Transport regulation offences'
#  'F30 Other government regulatory offences' 'F90 Miscellaneous offences'
#  'B60 Bribery' 'C90 Other drug offences']

# %% [markdown]
# We can see that this dataframe has:
# - 26635 rows and 10 columns
# - historical data over 5 years (despite the file name)
# - 6 unique broad offence classifications (CSA Offence Division)
# - each CSA Offence Division has its own CSA Offence Subdivisions and CSA Offense Group
#
# Information on the CSA Offence Division can be found [here](https://www.crimestatistics.vic.gov.au/about-the-data/classifications-and-victorian-map-boundaries/offence-classification). We are only interested in the CSA Offence Division at the moment, so for simplicity, let's drop most of the columns we don't need, and rename some others. We also need to change the LGAs to uppercase and the hyphenation for COLAC-OTWAY so as to match the json data.

# %%
Victorian_ERP = crime2_df['Victorian ERP'][0]
crime2_df.drop(['Police Region', 'Police Service Area', 'CSA Offence Group', \
                'Victorian ERP'], axis=1, inplace=True)

crime2_df.rename(columns = {'Jul - Jun reference period':'Year', 'Local Government Area':'LGA', \
                            'CSA Offence Division':'Division', 'CSA Offence Subdivision':'Subdivision', \
                            'Offence Count':'Count'}, inplace=True)
crime2_df['LGA'] = crime2_df['LGA'].str.upper()
crime2_df.replace('COLAC-OTWAY', 'COLAC OTWAY', inplace=True)

# %% [markdown]
# Together, this 'cleaned-up' dataframe and the spatial data is our starting point for further analysis.

# %% [markdown]
# ### 4.1 Crime rate by division

# %% [markdown]
# [[ go back to the top ]](#Table-of-contents)

# %% [markdown]
# We now need to aggregate the data appropriately so we have the counts for each offence division in each LGA. We can then calculate the LGA Offence Rate for each LGA and each offence division for years 2013-2017.

# %%
def rates_by_LGA(df):
    '''
    Calculates all crime rate by LGA.
    '''
    df2 = df.pivot_table(index=['Year','LGA','LGA ERP'], values='Count', aggfunc=sum)
    df2.reset_index(inplace=True)
    df2['Rate'] = (df2['Count'] / df2['LGA ERP'] * 100000).round().astype('int')
    return df2

def rates_by_LGA_and_div(df, division):
    '''
    Calculates crime rate by LGA and division.
    '''
    df2 = df.pivot_table(index=['Year','LGA','Division','LGA ERP'], values='Count', aggfunc=sum)
    df2.reset_index(inplace=True)
    df2['Rate'] = (df2['Count'] / df2['LGA ERP'] * 100000).round().astype('int')
    df2 = df2[df2['Division']==division]
    return df2

def rates_by_criteria(df, year, division=None, subdivision=None, sort=False):
    '''
    Calculates crime rate by LGA for a specific division.
    '''
    if division == None:
        df2 = rates_by_LGA(df)
        df2 = df2[df2['Year']==year]
        if sort:
            df2 = df2.sort_values(by='Rate', ascending=False)
        return df2.drop(['Year', 'LGA ERP', 'Count'], axis=1)
    else:
        if subdivision == None:
            df2 = rates_by_LGA_and_div(df, division)
            df2 = df2[df2['Year']==year]
            if sort:
                df2 = df2.sort_values(by='Rate', ascending=False)
            return df2.drop(['Year', 'LGA ERP', 'Division', 'Count'], axis=1)
        else:
            df2 = rates_by_LGA_and_div_and_subdiv(df, division, subdivision)
            df2 = df2[df2['Year']==year]
            if sort:
                df2 = df2.sort_values(by='Rate', ascending=False)
            return df2.drop(['Year', 'LGA ERP', 'Division', 'Subdivision', 'Count'], axis=1)

# %% [markdown]
# The LGAs with highest Crimes against the person-related crime rates for 2017 are:

# %%
year = 2017
division = 'A Crimes against the person'
df = rates_by_criteria(crime2_df, year, division=division, sort=True)
df.head()
# Out:
#                      LGA  Rate
# 2097             LATROBE  3879
# 2138           MELBOURNE  3396
# 1925             BENALLA  2720
# 2222  NORTHERN GRAMPIANS  2681
# 2346        YARRIAMBIACK  2565

# %% [markdown]
# Here's the box plot for this distribtion:

# %%
ax = sns.boxplot(x=df['Rate'], width=0.5, flierprops=flierprops)
ax.set_title('VIC crime rates ({0}, year ending June {1})'.format(division,year))
ax.set(xlabel='Rate per 100,000 population')
plt.show()

# %% [markdown]
# Append missing data and merge...

# %%
new_df = fill_missing_LGAs(df, json_df)
df_merged = json_df.merge(new_df, how='right', on='LGA')

# %% [markdown]
# And here's the choropleth:

# %%
color_mapper = LinearColorMapper(palette=custom_palette,
                                 low=df_merged['Rate'][df_merged['Rate'] > 0.1].min(),
                                 high=df_merged['Rate'].max())

source = ColumnDataSource(data=dict(
    x=df_merged['Longs'], y=df_merged['Lats'],
    name=df_merged['LGA'], rate=df_merged['Rate']
))

TOOLS = "pan,wheel_zoom,reset,hover,save"

p = figure(
    title='VIC crime rates ({0}, year ending June {1})'.format(division,year),
    tools=TOOLS,
    x_axis_location=None, y_axis_location=None,
    plot_width=850, plot_height=600
)
p.grid.grid_line_color = None
p.patches('x', 'y', source=source,
          fill_color={'field': 'rate', 'transform': color_mapper},
          fill_alpha=0.8, line_color='black', line_width=0.3)

color_bar = ColorBar(color_mapper=color_mapper, ticker=LogTicker(),
                     label_standoff=6, border_line_color=None,
                     location=(480,560), orientation='horizontal',
                     height=15, width=300,
                     background_fill_alpha=0, scale_alpha=0.8,
                     title='Rate per 100,000 population'
                     )
p.add_layout(color_bar, 'center')

hover = p.select_one(HoverTool)
hover.point_policy = "follow_mouse"
hover.tooltips = [("LGA", "@name"),("Rate", "@rate")]

show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="f8260013-4720-474c-9e61-31194960dcda"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("f8260013-4720-474c-9e61-31194960dcda");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("f8260013-4720-474c-9e61-31194960dcda");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'f8260013-4720-474c-9e61-31194960dcda' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"b2e5022f-55fc-48b1-b2c5-72e1b7278947":{"roots":{"references":[{"attributes":{"fill_alpha":{"value":0.8},"fill_color":{"field":"rate","transform":{"id":"60b93b00-f94b-4201-b7f1-32f8157cf456","type":"LinearColorMapper"}},"line_width":{"value":0.3},"xs":{"field":"x"},"ys":{"field":"y"}},"id":"90d85968-bea9-4284-b9bb-7196dcc6b83e","type":"Patches"},{"attributes":{"plot":null,"text":"VIC crime rates (A Crimes against the person, year ending June 2017)"},"id":"7818ae93-06dc-4e5a-9826-1a82f211fc1f","type":"Title"},{"attributes":{"data_source":{"id":"9fd828e4-900e-4dc2-9ff1-5ca4d69c495d","type":"ColumnDataSource"},"glyph":{"id":"90d85968-bea9-4284-b9bb-7196dcc6b83e","type":"Patches"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"39b711ad-b252-4d53-be42-0e004590970c","type":"Patches"},"selection_glyph":null},"id":"10690474-0e24-42d7-b4bd-748ac530b87e","type":"GlyphRenderer"},{"attributes":{},"id":"d654c9de-1807-4ac1-b01c-2fc4da016887","type":"BasicTicker"},{"attributes":{"plot":{"id":"da3daec5-a2f2-41f6-bb76-f9e47e722bc4","subtype":"Figure","type":"Plot"}},"id":"e04f6a49-5f77-4f7e-9ea8-ce1eb9120162","type":"SaveTool"},{"attributes":{"callback":null,"column_names":["x","y","name","rate"],"data":{"name":["GLEN EIRA","GREATER DANDENONG","HUME","MARIBYRNONG","MONASH","WARRNAMBOOL","YARRA","BAYSIDE","GLENELG","WEST WIMMERA","MOUNT ALEXANDER","YARRA RANGES","BAW BAW","LODDON","GREATER BENDIGO","STRATHBOGIE","GANNAWARRA","CARDINIA","HEPBURN","GREATER SHEPPARTON","CASEY","WHITTLESEA","NILLUMBIK","MOONEE VALLEY","PORT PHILLIP","MAROONDAH","DAREBIN","MORELAND","LAKE MOUNTAIN ALPINE RESORT (UNINC)","MOYNE","HINDMARSH","MOUNT HOTHAM ALPINE RESORT (UNINC)","BASS COAST","BASS COAST","BASS COAST","MURRINDINDI","MURRINDINDI","YARRIAMBIACK","CORANGAMITE","ARARAT","HORSHAM","NORTHERN GRAMPIANS","GOLDEN PLAINS","COLAC OTWAY","SURF COAST","GREATER GEELONG","WYNDHAM","FRANKSTON","KINGSTON","KNOX","BRIMBANK","HOBSONS BAY","MOIRA","INDIGO","MELTON","MORNINGTON PENINSULA","WODONGA","EAST GIPPSLAND","SOUTHERN GRAMPIANS","PYRENEES","MOORABOOL","MANSFIELD","ALPINE","MANNINGHAM","BOROONDARA","WHITEHORSE","MOUNT BULLER ALPINE RESORT (UNINC)","FALLS CREEK ALPINE RESORT (UNINC)","MITCHELL","TOWONG","QUEENSCLIFFE","MOUNT STIRLING ALPINE RESORT (UNINC)","BALLARAT","BENALLA","WELLINGTON","LATROBE","MILDURA","MACEDON RANGES","WANGARATTA","BULOKE","CENTRAL GOLDFIELDS","STONNINGTON","SOUTH GIPPSLAND","CAMPASPE","MELBOURNE","FRENCH-ELIZABETH-SANDSTONE ISLANDS (UNINC)","GABO ISLAND (UNINC)","SWAN HILL","BANYULE","MOUNT BAW BAW ALPINE RESORT (UNINC)"],"rate":{"__ndarray__":"...","dtype":"float64","shape":[90]},"x":[[144.99705204,145.00003579,145.009166,145.01052136,145.01513662,145.03260723,145.04015202,145.04656539,145.05371815,145.07211172,145.07818255,145.0742074,145.08530643,145.08247563,145.07953336,145.03440114,145.02245805,145.02598778,145.00632168,145.00103804,144.99705204],[145.14170184,145.14344006,145.15672631,145.19249522,145.21915775,145.2193805,145.22919402,145.23405571,145.23286157,145.23535477,145.23195629,145.22725607,145.22745318,145.25199323,145.2466966,145.24624465,145.23940554,145.15625411,145.15026965,145.13642924,145.13351216,145.13929939,145.1460098,145.14094014,145.13109853,145.13658859,145.14170184],[144.67237956,144.66474887,144.65671888,144.64996039,144.64188488,144.63248154,144.63805194,144.64436811,144.65626399,144.65992123,144.66808634,144.68094227,144.67904052,144.68813826,144.69608938,144.70278171,144.70967877,144.71833948,144.71980482,144.72619542,144.73187673,144.73704562,144.74572752,144.75225352,144.75753037,144.76709125,144.77085494,144.77929785,144.83969088,144.87081071,144.87196272,144.86615306,144.87202535,144.8776002,144.88345806,144.89003133,144.95001863,144.97720535,144.97442191,144.97568211,144.97394017,144.97675015,144.97214192,144.96868665,144.9636858,144.95508136,144.95313333,144.96553634,144.96330167,144.96534267,144.96240888,144.95755073,144.95578518,144.95300484,144.95234861, ...

# %% [markdown]
# ### 4.2 Crime rate by subdivision

# %% [markdown]
# [[ go back to the top ]](#Table-of-contents)

# %% [markdown]
# I've written an ad hoc function (`rates_by_LGA_and_div_and_subdiv`) to calculate crime rate by LGA for a given division and subdivision. It takes in the 'cleaned-up' `pandas` dataframe (`crime2_df` in our case) and returns another.

# %%
def rates_by_LGA_and_div_and_subdiv(df, division, subdivision):
    '''
    Calculates crime rate by LGA, division and subdivision.
    '''
    df2 = df.pivot_table(index=['Year','LGA','Division','Subdivision','LGA ERP'], values='Count', aggfunc=sum)
    df2.reset_index(inplace=True)
    df2['Rate'] = (df2['Count'] / df2['LGA ERP'] * 100000).round().astype('int')
    df2 = df2[(df2['Division']==division) & (df2['Subdivision']==subdivision)]
    return df2

# %% [markdown]
# Let's us it to find the 2017 results for homicide and related crime rates.

# %%
year = 2017
division = 'A Crimes against the person'
subdivision = 'A10 Homicide and related offences'
df = rates_by_criteria(crime2_df, year, division=division, subdivision=subdivision, sort=True)
df.head()
# Out:
#                LGA  Rate
# 9043  YARRIAMBIACK    31
# 8246     MELBOURNE    31
# 8174     MANSFIELD    24
# 8809    WANGARATTA    19
# 7417       BENALLA    15

# %%
ax = sns.boxplot(x=df['Rate'], width=0.5, flierprops=flierprops)
ax.set_title('VIC crime rates ({0}, year ending June {1})'.format(subdivision,year))
ax.set(xlabel='Rate per 100,000 population')
plt.show()

# %%
new_df = fill_missing_LGAs(df, json_df)
df_merged = json_df.merge(new_df, how='right', on='LGA')

# %%
color_mapper = LinearColorMapper(palette=custom_palette,
                                 low=df_merged['Rate'][df_merged['Rate'] > 0.1].min(),
                                 high=df_merged['Rate'].max())

source = ColumnDataSource(data=dict(
    x=df_merged['Longs'], y=df_merged['Lats'],
    name=df_merged['LGA'], rate=df_merged['Rate']
))

TOOLS = "pan,wheel_zoom,reset,hover,save"

p = figure(
    title='VIC crime rates ({0}, year ending June {1})'.format(subdivision,year),
    tools=TOOLS,
    x_axis_location=None, y_axis_location=None,
    plot_width=850, plot_height=600
)
p.grid.grid_line_color = None
p.patches('x', 'y', source=source,
          fill_color={'field': 'rate', 'transform': color_mapper},
          fill_alpha=0.8, line_color='black', line_width=0.3)

color_bar = ColorBar(color_mapper=color_mapper, ticker=LogTicker(),
                     label_standoff=6, border_line_color=None,
                     location=(480,560), orientation='horizontal',
                     height=15, width=300,
                     background_fill_alpha=0, scale_alpha=0.8,
                     title='Rate per 100,000 population'
                     )
p.add_layout(color_bar, 'center')

hover = p.select_one(HoverTool)
hover.point_policy = "follow_mouse"
hover.tooltips = [("LGA", "@name"),("Rate", "@rate")]

show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="f2a73f29-39f2-489d-be9a-091e58b7b3e1"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("f2a73f29-39f2-489d-be9a-091e58b7b3e1");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("f2a73f29-39f2-489d-be9a-091e58b7b3e1");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'f2a73f29-39f2-489d-be9a-091e58b7b3e1' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"8cb55eca-bd6e-4202-a02b-240cb302abbc":{"roots":{"references":[{"attributes":{},"id":"db402698-32f8-4588-8a77-b1a0da8a32da","type":"ToolEvents"},{"attributes":{"callback":null},"id":"aace5c31-48c7-4b59-98d8-b7d47a66ea02","type":"DataRange1d"},{"attributes":{"plot":{"id":"d413f8db-4aa1-403b-b278-cc1e967b4707","subtype":"Figure","type":"Plot"}},"id":"94b6e678-a6d7-4599-9d37-2bd340ddf26c","type":"WheelZoomTool"},{"attributes":{"background_fill_alpha":{"value":0},"color_mapper":{"id":"bc536340-93f9-4f89-81f4-d43529bae6c9","type":"LinearColorMapper"},"formatter":{"id":"811d706f-45d8-4cfd-91a2-65a0707f1bf0","type":"BasicTickFormatter"},"height":15,"label_standoff":6,"location":[480,560],"orientation":"horizontal","plot":{"id":"d413f8db-4aa1-403b-b278-cc1e967b4707","subtype":"Figure","type":"Plot"},"scale_alpha":0.8,"ticker":{"id":"fce19b8f-f0d3-4887-82f7-7ed152901af2","type":"LogTicker"},"title":"Rate per 100,000 population","width":300},"id":"942a609e-88aa-44cd-98b8-0cb7b24e523a","type":"ColorBar"},{"attributes":{"plot_width":850,"renderers":[{"id":"4ab025ba-e9e2-49e7-ae34-75ea3d6baaf7","type":"Grid"},{"id":"f4962dfc-7b46-4a1e-916b-0b2faa268977","type":"Grid"},{"id":"3a53729a-d1b4-4c5e-b585-539b8a421a4b","type":"GlyphRenderer"},{"id":"942a609e-88aa-44cd-98b8-0cb7b24e523a","type":"ColorBar"}],"title":{"id":"5ba5beee-19b9-4208-a117-fdf2f183a106","type":"Title"},"tool_events":{"id":"db402698-32f8-4588-8a77-b1a0da8a32da","type":"ToolEvents"},"toolbar":{"id":"f7d6fe36-6314-46f6-a9c9-23e0b469c28e","type":"Toolbar"},"x_range":{"id":"aace5c31-48c7-4b59-98d8-b7d47a66ea02","type":"DataRange1d"},"y_range":{"id":"8b30a8c0-26a5-4c62-9def-d754b1cf191f","type":"DataRange1d"}},"id":"d413f8db-4aa1-403b-b278-cc1e967b4707","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"811d706f-45d8-4cfd-91a2-65a0707f1bf0","type":"BasicTickFormatter"},{"attributes":{},"id":"cec04fa6-5f7c-4e7b-9f53-01612e15357f","type":"BasicTicker"},{"attributes":{"dimension":1,"grid_line_color":{"value":null},"plot":{"id":"d413f8db-4aa1-403b-b278-cc1e967b4707","subtype":"Figure","type":"Plot"},"ticker":{"id":"cec04fa6-5f7c-4e7b-9f53-01612e15357f","type":"BasicTicker"}},"id":"f4962dfc-7b46-4a1e-916b-0b2faa268977","type":"Grid"},{"attributes":{"plot":{"id":"d413f8db-4aa1-403b-b278-cc1e967b4707","subtype":"Figure","type":"Plot"}},"id":"bfa5cbab-b740-400a-b3ec-92fea77f04a9","type":"PanTool"},{"attributes":{"grid_line_color":{"value":null},"plot":{"id":"d413f8db-4aa1-403b-b278-cc1e967b4707","subtype":"Figure","type":"Plot"},"ticker":{"id":"d9cbf155-912f-4968-b20a-b3e687da0a69","type":"BasicTicker"}},"id":"4ab025ba-e9e2-49e7-ae34-75ea3d6baaf7","type":"Grid"},{"attributes":{},"id":"fce19b8f-f0d3-4887-82f7-7ed152901af2","type":"LogTicker"},{"attributes":{"plot":{"id":"d413f8db-4aa1-403b-b278-cc1e967b4707","subtype":"Figure","type":"Plot"}},"id":"7a109918-f060-43be-b543-257fb6c22b51","type":"ResetTool"},{"attributes":{"plot":null,"text":"VIC crime rates (A10 Homicide and related offences, year ending June 2017)"},"id":"5ba5beee-19b9-4208-a117-fdf2f183a106","type":"Title"},{"attributes":{"data_source":{"id":"5c947919-5a47-4437-9375-87bb0df9a3f3","type":"ColumnDataSource"},"glyph":{"id":"2f88853a-9e83-4f1a-a82b-3fd2d7b62b6a","type":"Patches"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"9bb27340-a6ec-4b4a-9ba5-302891547a56","type":"Patches"},"selection_glyph":null},"id":"3a53729a-d1b4-4c5e-b585-539b8a421a4b","type":"GlyphRenderer"},{"attributes":{"high":31.0,"low":1.0,"palette":["#fed976","#feb24c","#fd8d3c","#fc4e2a","#e31a1c","#b10026"]},"id":"bc536340-93f9-4f89-81f4-d43529bae6c9","type":"LinearColorMapper"},{"attributes":{"plot":{"id":"d413f8db-4aa1-403b-b278-cc1e967b4707","subtype":"Figure","type":"Plot"}},"id":"a19820c1-50f2-41a3-abfe-b1d6a4df7f12","type":"SaveTool"},{"attributes":{"callback":null,"column_names":["x","y","name","rate"],"data":{"name":["GLEN EIRA","GREATER DANDENONG","HUME","MARIBYRNONG","MONASH","WARRNAMBOOL","YA ...

# %% [markdown]
# ## 5. Widgets

# %% [markdown]
# [[ go back to the top ]](#Table-of-contents)

# %% [markdown]
# A particularly useful improvement would be to include [interactive widgets](https://ipywidgets.readthedocs.io/en/stable/examples/Using%20Interact.html) (e.g. pull-down selection menus) to save re-running code. Here's a couple of functions to make things easier:

# %%
def make_title(year, division=None, subdivision=None):
    
    if division == None:
        title = 'VIC crime rates (all crime, year ending June {0})'.format(year)
    else:
        if subdivision == None:
            title = 'VIC crime rates ({0}) year ending June {1})'.format(division, year)
        else:
            title = 'VIC crime rates ({0}) year ending June {1})'.format(subdivision, year)
    
    return title

def create_choropleth(crime_df, spatial_df, year, division=None, subdivision=None):
    
    df = rates_by_criteria(crime_df, year, division=division, subdivision=subdivision)
    new_df = fill_missing_LGAs(df, spatial_df)
    df_merged = spatial_df.merge(new_df, how='right', on='LGA')

    title = make_title(year, division=division, subdivision=subdivision)

    custom_palette = YlOrRd7[::-1][1:]
    color_mapper = LinearColorMapper(palette=custom_palette,
                                     low=df_merged['Rate'][df_merged['Rate'] > 0.1].min(),
                                     high=df_merged['Rate'].max())

    source = ColumnDataSource(data=dict(
        x=df_merged['Longs'], y=df_merged['Lats'],
        name=df_merged['LGA'], rate=df_merged['Rate']
    ))

    TOOLS = "pan,wheel_zoom,reset,hover,save"

    p = figure(
        title=title,
        tools=TOOLS,
        x_axis_location=None, y_axis_location=None,
        plot_width=850, plot_height=600
    )
    p.grid.grid_line_color = None
    p.patches('x', 'y', source=source,
              fill_color={'field': 'rate', 'transform': color_mapper},
              fill_alpha=0.8, line_color='black', line_width=0.3)

    color_bar = ColorBar(color_mapper=color_mapper, ticker=LogTicker(),
                         label_standoff=6, border_line_color=None,
                         location=(480,560), orientation='horizontal',
                         height=15, width=300,
                         background_fill_alpha=0, scale_alpha=0.8,
                         title='Rate per 100,000 population'
                         )
    p.add_layout(color_bar, 'center')

    hover = p.select_one(HoverTool)
    hover.point_policy = "follow_mouse"
    hover.tooltips = [("LGA", "@name"),("Rate", "@rate")]
    
    return p

# %%
import numpy as np
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets

# %% [markdown]
# Create some dictionaries for the pull-down menus:

# %%
div_list_dict = {}
subdiv_list_dict = {}
div_list_dict['All crime'] = None
subdiv_list_dict['All crime'] = {'All crime':None}
for div in list(crime2_df['Division'].unique()):
    div_list_dict[div[2:]] = div
    subdiv_dict = {}
    subdiv_dict['All crime'] = None
    subdiv_list = list(crime2_df[crime2_df['Division']==div]['Subdivision'].unique())
    for subdiv in subdiv_list:
        subdiv_dict[subdiv[4:]] = subdiv
    subdiv_list_dict[div[2:]] = subdiv_dict
    
year_list = list(np.sort(np.asarray(crime2_df['Year'].unique()))[::-1])
# Out:
# [2017, 2016, 2015, 2014, 2013]

# %% [markdown]
# And here's the more interactive choropleth:

# %%
year_widget = widgets.Dropdown(
            options = year_list,
            value = 2017,
            description = 'Year',
            disabled = False,)

div_widget = widgets.Dropdown(
            options = list(div_list_dict.keys()),
            value = 'All crime',
            description = 'Division',
            disabled = False,)

subdiv_widget = widgets.Dropdown(
            options = list(subdiv_list_dict['All crime'].keys()),
            value = 'All crime',
            description = 'Subdivision',
            disabled = False,)

def update_subdiv(*args):
    if div_widget.value == 'All crime':
        subdiv_widget.options = ['All crime']
    else:
        subdiv_widget.options = list(subdiv_list_dict[div_widget.value].keys())
    
div_widget.observe(update_subdiv, 'value')

def LGAmap(Year, Division, Subdivision):
    p = create_choropleth(crime2_df, json_df,
                          Year,
                          division=div_list_dict[Division],
                          subdivision=subdiv_list_dict[Division][Subdivision],
                         )
    show(p)

interact(LGAmap, Year=year_widget, Division=div_widget, Subdivision=subdiv_widget);

# %% [markdown]
# ## 6. Final remarks

# %% [markdown]
# [[ go back to the top ]](#Table-of-contents)

# %% [markdown]
# There's clearly many improvements that can be made to the procedures above. As pointed out at the beginning, this is just a walkthrough of the steps involved in analysing and visualising data spatially. The code I've written here is certainly not perfect or optimal... I'm an astrophysicist by trade, not a software engineer (but I'm learning!)
#
# If you've never created a choropleth before and need to I hope you've found something here of use.
